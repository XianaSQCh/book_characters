# %%
import os
import io
import re
import multiprocessing
import pickle

# %%
import neuralcoref
import spacy

print('spacy version:', spacy.__version__)
print('neuralcoref version:', neuralcoref.__version__)
# Out:
# spacy version: 2.1.3
# neuralcoref version: 4.0.0

# %%
def write_data_to_disk(file, data):
    with open(file, 'wb') as fid:
        pickle.dump(data, fid)

def load_data_from_disk(file):
    with open(file, 'rb') as fid:
        data = pickle.load(fid)
    return data

# %% [markdown]
# # Reconhecimento de entidades

# %%
def read_file(path):
    try:
        with io.open(path, 'r', encoding='utf-8') as f:
            return f.read()
    except UnicodeDecodeError:
        try:
            with io.open(path, 'r', encoding='latin-1') as f:
                return f.read()
        except UnicodeDecodeError:
            return "Could not decode"

# %%
def extract_paragraphs(folder, file):
    path = os.path.join(folder, file) # name file

    if os.path.isfile(path):
        content = read_file(path)
        print(f"Content of book ... {file}")

        paragraphs = content.split('\n\n')

        return paragraphs
    return []

# %%
def new_paragraphs(paragraphs):
    paragraphs_new = []
    contents = []
    chapters = []
    old_idx = 0

    for paragraph in paragraphs:
        lines = paragraph.split('\n')

        if re.match('[IVXLCDM\d]+[\.]*', lines[0].upper().strip()):
            if not contents:
                contents = [" ".join(line.lower().split()) for line in lines]
                
                if not contents:
                    print("Not found content", id_file)
                    exit()
            continue

        if paragraph.lower().strip() in contents:
            if old_idx == 0:
                old_idx = len(paragraphs_new)
            else:
                current_idx = len(paragraphs_new)
                chapter = "\n\n".join(paragraphs_new[old_idx:current_idx])
                chapters.append(chapter)
                old_idx = current_idx
            continue

        if not re.match('.*[\w]+.*', paragraph):
            continue

        paragraphs_new.append(paragraph)

        if old_idx != 0:
            chapter = "\n\n".join(paragraphs_new[old_idx:])
            chapters.append(chapter)
        
    return paragraphs_new

# %%
def process_paragraph(paragraph, nlp):
    paragraph = paragraph.replace('\n', ' ')
    paragraph = " ".join(paragraph.split())
    doc = nlp(paragraph)
    doc_coref = doc._.coref_resolved
    doc_coref = nlp(doc_coref)

    entities = [ent.text for ent in doc_coref.ents if ent.label_ == "PERSON"]

    return entities

def extract_entities_from_paragraphs(paragraphs_to_process, nlp):
    """
    
    return:
    
    data: 
        (num paragraph, len_words, list_entities)
        
        [(5, 79, ['Kidd’s', 'Whoso']), ...]
    """
    
    data = []
    geral_entities = set()

    with multiprocessing.Pool() as pool:
        results = pool.starmap(process_paragraph, [(p, nlp) for p in paragraphs_to_process])

    for i, entities in enumerate(results):
        if entities:
            len_words = len(paragraphs_to_process[i].split())
            geral_entities.update(entities) # adiciona entities únicas
            data.append((i, len_words, entities))
            # print(i, len_words, entities)

    return data, list(geral_entities)

# %%
def all_entities(folder, file):     
    paragraphs = extract_paragraphs(folder, file)
    paragraphs_new = new_paragraphs(paragraphs)
    
    print('Número de parágrafos:', len(paragraphs))
    print('Número de parágrafos com personagens: ', len(paragraphs_new))     
    
    nlp = spacy.load("en_core_web_sm")
    neuralcoref.add_to_pipe(nlp)
    
    data, geral_entities = extract_entities_from_paragraphs(paragraphs_new, nlp)
    
    return data, geral_entities

# %%
def pk_data_entities(folder, df):
    
    files_ordered = sorted(os.listdir(folder), key=lambda name:int(name.split('_')[0]))
    
    for i in range(len(files_ordered)):
        file = files_ordered[i]
        print('\n')
        
        data, geral_entities = all_entities(folder, file)
        
        index = df["Index"][i]
        
        write_data_to_disk('dados/data_' + folder + '_' + str(index)+ '.pk', data)
        write_data_to_disk('dados/entities_' + folder + '_' + str(index)+ '.pk', geral_entities)

# %% [markdown]
# # Criação de rede de co-ocorrência

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
def cooccurrence_matrix(data, entities_list):
    # Inicializa a matriz de coocorrência
    cooccurrence_matrix = np.zeros((len(entities_list), len(entities_list)), dtype=int)

    # Preenche a matriz de coocorrência
    for _, _, paragraph_entities in data:
        
        for i in range(len(entities_list)):
            if entities_list[i] in paragraph_entities:
                
                for j in range(i, len(entities_list)):
                    if entities_list[j] in paragraph_entities:
                        cooccurrence_matrix[i][j] += 1
                        if i != j:
                            cooccurrence_matrix[j][i] += 1
    return np.array(cooccurrence_matrix)

# %%
def edge_list(entities_list, co_matrix):
    edge_list = []

    for i in range(len(entities_list)):
        for j in range(i + 1, len(entities_list)):
            weight = co_matrix[i][j]
            if weight > 0:
                edge_list.append((entities_list[i], entities_list[j], {'weight': weight}))
    
    return edge_list

# %%
def plot_network_degree(G, name_list, folder, name, index):
    
    # Atribuir uma cor única a cada nó
    node_colors = range(len(name_list))

    # Identifica os 15 nós com maior grau
    degrees = dict(G.degree())
    top_degree_nodes = sorted(degrees, key=degrees.get, reverse=True)[:15]

    # Determina as arestas que conectam os nós de maior grau
    edges_of_top_degree_nodes = [(u, v) for u, v in G.edges() if u in top_degree_nodes and v in top_degree_nodes]

    # Posicionamento dos nós aleatório
    pos = nx.random_layout(G)

    plt.figure(figsize=(12, 12))

    # Desenha a rede
    nx.draw(G,
            pos=pos,
            node_color=node_colors,
            cmap=plt.get_cmap('OrRd_r'),  # mapa de cores
            node_size=35,  # Tamanho dos nós
            edge_color="#E1E5EA", # "#DBDFEA"  # Cor das arestas
            with_labels=False,  # Não mostra rótulos dos nós
            alpha= 0.7,
           ) 

    # Adiciona as arestas dos nós de maior grau em uma cor diferente
    nx.draw(G,
            pos=pos,
            node_color=node_colors,
            cmap=plt.get_cmap('OrRd_r'),  # mapa de cores
            node_size=35,  # Tamanho dos nós
            edgelist=edges_of_top_degree_nodes,
            edge_color='red',  # Cor das arestas dos nós de maior grau
            width=1.0,  # Largura das arestas
            alpha=0.2)  # Transparência das arestas


    for node in top_degree_nodes:
        x, y = pos[node]
        plt.annotate(node, (x, y), ha='center', va='center', fontsize=10,
                     # fontweight='heavy',
                     color='#461959', #B80D57 #99235C
                     backgroundcolor='white',
                     bbox=dict(boxstyle='round,pad=0.2', edgecolor='#D3CEDF', facecolor='#F9F5F6'))
    
    legend_text = f"Personagens (nós): {G.number_of_nodes()}\nOcorrência (arestas): {G.number_of_edges()}"
    plt.figtext(0.1, 0.94, legend_text, fontsize=11, color='#461959', 
                bbox=dict(facecolor='white', edgecolor='#D3CEDF', boxstyle='round,pad=0.6'))

    plt.title(name , fontsize=18, style='italic', color='#461959', va='baseline')
    plt.axis('off')
    plt.savefig("graphs/graph_" + folder + "_" + str(index) + '.png', dpi=300, bbox_inches='tight')
    plt.show()

# %% [markdown]
# # Medidas de centralidade

# %%
def medidas(G):
    
    K = dict(nx.degree_centrality(G)) # Centralidade de grau
    CC = dict(nx.clustering(G)) # Clustering coeficient
    CLC = dict(nx.closeness_centrality(G)) # Closeness centrality
    B = dict(nx.betweenness_centrality(G, endpoints=True)) # Betweenness centrality
    EC = dict(nx.eigenvector_centrality(G, max_iter=1000)) # Eigenvetor centrality
    PR = dict(nx.pagerank(G, alpha=0.85)) # PageRank
    
    
    df = pd.DataFrame({'K':list(K.values()),
                       'CC':list(CC.values()),
                       'CLC':list(CLC.values()),
                       'B':list(B.values()),
                       'EC':list(EC.values()),
                       'PR':list(PR.values())})
    display(df)
    
    # Vetor com valores médios das medidas de rede de co-ocorrência
    medidas = list(df.mean())
    
    return medidas

# %%
dfs = pd.read_csv('catalog_v0.xlsx - success.csv')

pk_data_entities(folder="success", df=dfs)
# Out:
# Content of book ... 1_BesideTheBonnieBrierBush_IanMaclaren_cleared.txt
# Número de parágrafos: 1358
# Número de parágrafos com personagens:  1158
#
#
# Content of book ... 2_Trilby_GeorgeDuMaurier_cleared.txt
# Número de parágrafos: 2407
# Número de parágrafos com personagens:  1987
#
#
# Content of book ... 3_TheAdventuresOfCaptainHorn_FrankRichardStockton_cleared.txt
# Número de parágrafos: 1945
# Número de parágrafos com personagens:  1608
#
#
# Content of book ... 4_TheManxman_HallCaine_cleared.txt
# Número de parágrafos: 5701
# Número de parágrafos com personagens:  5227
#
#
# Content of book ... 5_ThePrincessAline_RichardHardingDavis_cleared.txt
# Número de parágrafos: 431
# Número de parágrafos com personagens:  357
#
#
# Content of book ... 6_TheMaster_IsraelZangwill_cleared.txt
# Número de parágrafos: 3962
# Número de parágrafos com personagens:  3511
#
#
# Content of book ... 7_ThePrisonerOfZenda_AnthonyHope_cleared.txt
# Número de parágrafos: 1762
# Número de parágrafos com personagens:  1538
#
#
# Content of book ... 8_Degeneration_MaxNordau_cleared.txt
# Número de parágrafos: 1835
# Número de parágrafos com personagens:  1346
#
#
# Content of book ... 9_MyLadyNobody_MaartenMaartens_cleared.txt
# Número de parágrafos: 4095
# Número de parágrafos com personagens:  3714
#
#
# Content of book ... 10_TomGrogan_FrancisHopkinsonSmith_cleared.txt
# Número de parágrafos: 803
# Número de parágrafos com personagens:  695
#
#
# Content of book ... 11_ALadyOfQuality_FrancesHodgsonBurnett_cleared.txt
# Número de parágrafos: 1501
# Número de parágrafos com personagens:  1326
#
#
# Content of book ... 12_TheSeatsOfTheMighty_cleared.txt
# Número de parágrafos: 1973
# Número de parágrafos com personagens:  1572
#
#
# Content of book ... 13_ASingularLife_ElizabethStuartPhelpsWard_cleared.txt
# Número de parágrafos: 2486
# Número de parágrafos com personagens:  2250
#
#
# Content of book ... 14_TheDamnationOfTheronWare_HaroldFrederic_cleared.txt
# Número de parágrafos: 1705
# Número de parágrafos com personagens:  1488
#
#
# Content of book ... 15_AHouseBoatOnTheStyx_JohnKendrickBangs_cleared.txt
# Número de parágrafos: 672
# Número de parágrafos com personagens:  622
#
#
# Content of book ... 16_TheRedBadgeOfCourage_StephenCrane_cleared.txt
# Número de parágrafos: 1016
# Número de parágrafos com personagens:  902
#
#
# Content of book ... 17_SentimentalTommy_JMBarrie_cleared.txt
# Número de parágrafos: 2515
# Número de parágrafos com personagens:  2276
#
#
# Content of book ... 18_QuoVadis_HenrykSienkiewicz_cleared.txt
# Número de parágrafos: 3851
# Número de parágrafos com personagens:  3270
#
#
# Content of book ... 19_TheChoirInvisible_JamesLaneAllen_cleared.txt
# Número de parágrafos: 1029
# Número de parágrafos com personagens:  947
#
#
# Content of book ... 20_OnTheFaceOfTheWaters_FloraAnnieSteel_cleared.txt
# Número de parágrafos: 2897
# Número de parágrafos com personagens:  2595
#
#
# Content of book ... 21_TheHonorablePeterStirling_PaulLeicesterFord_cleared.txt
# Número de parágrafos: 4914
# Número de parágrafos com personagens:  4468
#
#
# Content of book ... 22_HughWynne_SilasWeirMitchell_cleared.txt
# Número de parágrafos: 2708
# Número de parágrafos com personagens:  2007
#
#
# Content of book ... 23_PenelopesProgress_KateDouglasWiggin_cleared.txt
# Número de parágrafos: 1111
# Número de parágrafos com personagens:  920
#
#
# Content of book ... 24_HelbeckOfBannisdale_MaryAugustaWard_cleared.txt
# Número de parágrafos: 1659
# Número de parágrafos com personagens:  1431
#
#
# Content of book ... 25_ThePrideOfJennico_EgertonCastle_cleared.txt
# Número de parágrafos: 1156
# Número de parágrafos com personagens:  873
#
#
# Content of book ... 26_Shrewsbury_StanleyJWeyman_cleared.txt
# Número de parágrafos: 2301
# Número de parágrafos com personagens:  1854
#
#
# Content of book ... 27_DavidHarum_EdwardNoyesWestcott_cleared.txt
# Número de parágrafos: 2264
# Número de parágrafos com personagens:  2012
#
#
# Content of book ... 28_WhenKnightoodWasInFlower_CharlesMajor_cleared.txt
# Número de parágrafos: 1496
# Número de parágrafos com personagens:  1185
#
#
# Content of book ... 29_RichardCarvel_WinstonChurchill_cleared.txt
# Número de parágrafos: 3894
# Número de parágrafos com personagens:  3216
#
#
# Content of book ... 30_RedRock_ThomasNelsonPage_cleared.txt
# Número de parágrafos: 4046
# Número de parágrafos com personagens:  3540
#
#
# Content of book ... 31_Aylwin_TheodoreWattsDunton_cleared.txt
# Número de parágrafos: 3349
# Número de parágrafos com personagens:  2777
#
#
# Content of book ... 32_MrDooleyInPeaceAndWar_FinleyPeterDunne_cleared.txt
# Número de parágrafos: 538
# Número de parágrafos com personagens:  387
#
#
# Content of book ... 33_ToHaveAndToHold_MaryJohnston_cleared.txt
# Número de parágrafos: 2023
# Número de parágrafos com personagens:  1621
#
#
# Content of book ... 34_RedPottage_MaryCholmondeley_cleared.txt
# Número de parágrafos: 3037
# Número de parágrafos com personagens:  2551
#
#
# Content of book ... 35_UnleavenedBread_RobertGrant_cleared.txt
# Número de parágrafos: 1359
# Número de parágrafos com personagens:  1159
#
#
# Content of book ... 36_EbenHolden_IrvingBacheller_cleared.txt
# Número de parágrafos: 2310
# Número de parágrafos com personagens:  1926
#
#
# Content of book ... 37_TheRedemptionOfDavidCorson_CharlesFredericGoss_cleared.txt
# Número de parágrafos: 2280
# Número de parágrafos com personagens:  2014
#
#
# Content of book ... 38_AliceOfOldVincennes_MauriceThompson_cleared.txt
# Número de parágrafos: 2299
# Número de parágrafos com personagens:  2042
#
#
# Content of book ... 39_TheHelmetOfNavarre_BerthaRunkle_cleared.txt
# Número de parágrafos: 3928
# Número de parágrafos com personagens:  3328
#
#
# Content of book ... 40_ThePuppetCrown_HaroldMacGrath_cleared.txt
# Número de parágrafos: 2984
# Número de parágrafos com personagens:  2711
#
#
# Content of book ... 41_TheLifeAndDeathOfRichardYeaAndNay_MauriceHewlett_cleared.txt
# Número de parágrafos: 1770
# Número de parágrafos com personagens:  1547
#
#
# Content of book ... 42_Graustark_GeorgeBarrMcCutcheon_cleared.txt
# Número de parágrafos: 2146
# Número de parágrafos com personagens:  1992
#
#
# Content of book ... 43_TheVirginian_OwenWister_cleared.txt
# Número de parágrafos: 3233
# Número de parágrafos com personagens:  2911
#
#
# Content of book ... 44_MrsWiggsOfTheCabbagePatch_AliceCaldwellHegan_cleared.txt
# Número de parágrafos: 611
# Número de parágrafos com personagens:  519
#
#
# Content of book ... 45_TheMississippiBubble_EmersonHough_cleared.txt
# Número de parágrafos: 2022
# Número de parágrafos com personagens:  1732
#
#
# Content of book ... 46_TheHoundOfTheBaskervilles_ArthurConanDoyle_cleared.txt
# Número de parágrafos: 1523
# Número de parágrafos com personagens:  1397
#
#
# Content of book ... 47_TheTwoVanrevels_BoothTarkington_cleared.txt
# Número de parágrafos: 1090
# Número de parágrafos com personagens:  933
#
#
# Content of book ... 48_TheBlueFlower_HenryVanDyke_cleared.txt
# Número de parágrafos: 950
# Número de parágrafos com personagens:  823
#
#
# Content of book ... 49_SirRichardCalmady_LucasMalet_cleared.txt
# Número de parágrafos: 4012
# Número de parágrafos com personagens:  3556
#
#
# Content of book ... 50_ThePit_FrankNorris_cleared.txt
# Número de parágrafos: 2872
# Número de parágrafos com personagens:  2591
#
#
# Content of book ... 51_TheOneWoman_ThomasDixonJr_cleared.txt
# Número de parágrafos: 2668
# Número de parágrafos com personagens:  2419
#
#
# Content of book ... 52_TheLittleShepherdOfKingdomCome_JohnFoxJr_cleared.txt
# Número de parágrafos: 1888
# Número de parágrafos com personagens:  1620
#
#
# Content of book ... 53_TheDeliverance_EllenGlasgow_cleared.txt
# Número de parágrafos: 2862
# Número de parágrafos com personagens:  2560
#
#
# Content of book ... 54_TheMasquerader_KatherineCecilThurston_cleared.txt
# Número de parágrafos: 2205
# Número de parágrafos com personagens:  1715
#
#
# Content of book ... 55_InTheBishopsCarriage_MiriamMichelson_cleared.txt
# Número de parágrafos: 1756
# Número de parágrafos com personagens:  1414
#
#
# Content of book ... 56_MyFriendProspero_HenryHarland_cleared.txt
# Número de parágrafos: 1507
# Número de parágrafos com personagens:  1299
#
#
# Content of book ... 57_TheSilentPlaces_StewartEdwardWhite_cleared.txt
# Número de parágrafos: 1194
# Número de parágrafos com personagens:  989
#
#
# Content of book ... 58_TheGardenOfAllah_RobertHichens_cleared.txt
# Número de parágrafos: 5201
# Número de parágrafos com personagens:  4880
#
#
# Content of book ... 59_TheHouseOfMirth_EdithWharton_cleared.txt
# Número de parágrafos: 1922
# Número de parágrafos com personagens:  1488
# Content of book ... 60_ThePrincessPasses_CNWilliamson_cleared.txt
# Número de parágrafos: 2064
# Número de parágrafos com personagens:  1688
#
#
# Content of book ... 61_TheFightingChance_RobertWChambers_cleared.txt
# Número de parágrafos: 4113
# Número de parágrafos com personagens:  3865
#
#
# Content of book ... 62_TheHouseOfAThousandCandles_MeredithNicholson_cleared.txt
# Número de parágrafos: 2334
# Número de parágrafos com personagens:  1983
#
#
# Content of book ... 63_TheJungle_UptonSinclair_cleared.txt
# Número de parágrafos: 1525
# Número de parágrafos com personagens:  1289
#
#
# Content of book ... 64_TheAwakeningOfHelenaRichie_MargaretDeland_cleared.txt
# Número de parágrafos: 2595
# Número de parágrafos com personagens:  2278
#
#
# Content of book ... 65_TheSpoilers_RexBeach_cleared.txt
# Número de parágrafos: 1997
# Número de parágrafos com personagens:  1827
#
#
# Content of book ... 66_TheBrassBowl_LouisJosephVance_cleared.txt
# Número de parágrafos: 1937
# Número de parágrafos com personagens:  1721
#
#
# Content of book ... 67_SatanSanderson_HallieErminieRives_cleared.txt
# Número de parágrafos: 1584
# Número de parágrafos com personagens:  1295

# %%
dfo = pd.read_csv('catalog_v0.xlsx - other.csv')

pk_data_entities(folder="other", df=dfo)

# %%
def medidas_folder(folder, df):
    
    M = list()
    for i in range(len(df)):

        index = df["Index"][i]
        name = df["Title"][i] + '\n' + df['Author'][i]

        data = load_data_from_disk('dados/data_' + folder + '_' + str(index)+ '.pk')
        entities_list = load_data_from_disk('dados/entities_' + folder + '_' + str(index)+ '.pk')

        # Matriz de coocorrência
        co_matrix = cooccurrence_matrix(data, entities_list)
        print("Matriz de Co-ocorrência", co_matrix.shape)

        # Lista de arestas
        edgelist = edge_list(entities_list, co_matrix)

        # Rede
        G = nx.Graph()
        G.add_nodes_from(entities_list)
        G.add_edges_from(edgelist)

        print('Personagens (nodes)', G.number_of_nodes())
        print('Ocorrência (edges)', G.number_of_edges())

        # Visualização de rede - 15 personagens com maior grau
        plot_network_degree(G, entities_list, folder, name, index)

        medidas_rede = medidas(G)
        print('Valores médios das medidas de rede:\n', medidas_rede)

        M.append(medidas_rede)
        
    return M

# %%
dfs = pd.read_csv('catalog_v0.xlsx - success.csv')
medidas_success = medidas_folder(folder="success", df=dfs)

# %%
dfo = pd.read_csv('catalog_v0.xlsx - other.csv')
medidas_other = medidas_folder(folder="other", df=dfo)

# %% [markdown]
# # Classificação

# %%
# other - Others (1895 - 1923)
dfo = pd.read_csv('catalog_v0.xlsx - other.csv')
dfo['Classe'] = 0
dfo['Medidas'] = medidas_other
dfo.head()

# %%
# success- Publishers Weekly’s Bestselling Novels
dfs = pd.read_csv('catalog_v0.xlsx - success.csv')
dfs['Classe'] = 1
dfs['Medidas'] = medidas_success
dfs.head()

# %%
concat = pd.concat([dfs, dfo], axis=0)
concat = concat.sample(frac=1).reset_index(drop=True)
display(concat)

# %%
for i in range(len(concat)):
    name = ''.join(concat["Title"][i].split())
    index = concat["Index"][i]
    namesearch = str(index) + '_' + str(name)
    print(namesearch)

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from collections import Counter
